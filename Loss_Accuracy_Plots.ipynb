# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
epoch = np.arange(1, 11)
train_loss_unet_higher_depth = [0.4514, 0.3855, 0.3766, 0.3414, 0.3336, 0.3507, 0.3288, 0.3336, 0.3142, 0.3225]
val_loss_unet_higher_depth = [0.3673, 0.3515, 0.3879, 0.3553, 0.3393, 0.3299, 0.3374, 0.3275, 0.3587, 0.3319]
train_acc_unet_higher_depth = [0.8041, 0.8160, 0.8176, 0.8348, 0.8337, 0.8160, 0.8274, 0.8197, 0.8300, 0.8227]
val_acc_unet_higher_depth = [0.8263, 0.8341, 0.8160, 0.8328, 0.8306, 0.8354, 0.8312, 0.8303, 0.8312, 0.8302]

# %%
plt.plot(epoch, train_loss_unet_higher_depth, label = 'Train loss')
plt.plot(epoch, val_loss_unet_higher_depth, label = 'Validation loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss by Epoch for UNet Variation 3 (Higher Depth)')
plt.show()

# %%
plt.plot(epoch, train_acc_unet_higher_depth, label = 'Train accuracy')
plt.plot(epoch, val_acc_unet_higher_depth, label = 'Validation accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy by Epoch for UNet Variation 3 (Higher Depth)')
plt.show()

# %%
train_loss_unet_bridge_variation = [0.3332, 0.3090, 0.2959, 0.2945, 0.2785, 0.2760, 0.2663, 0.2592, 0.2521, 0.2449]
val_loss_unet_bridge_variation = [0.3558, 0.3591, 0.3192, 0.3281, 0.3026, 0.3015, 0.3187, 0.2961, 0.3022, 0.3633]
train_acc_unet_bridge_variation = [0.8243, 0.8265, 0.8519, 0.8526, 0.8600, 0.8619, 0.8673, 0.8703, 0.8759, 0.8788]
val_acc_unet_bridge_variation = [0.8072, 0.7820, 0.8321, 0.8210, 0.8387, 0.8399, 0.8256, 0.8475, 0.8361, 0.8399]

# %%
plt.plot(epoch, train_loss_unet_higher_width, label = 'Train loss')
plt.plot(epoch, val_loss_unet_higher_width, label = 'Validation loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss by Epoch for UNet Variation 2 (Bridge Variation)')
plt.show()

# %%
plt.plot(epoch, train_acc_unet_higher_width, label = 'Train accuracy')
plt.plot(epoch, val_acc_unet_higher_width, label = 'Validation accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy by Epoch for UNet Variation 2 (Bridge Variation)')
plt.show()

# %%
train_loss_unet_smaller_filter = [0.6962, 0.6841, 0.6776, 0.6721, 0.6664, 0.6602, 0.6547, 0.6490, 0.6441, 0.6372]
val_loss_unet_smaller_filter = [0.6871, 0.6811, 0.6750, 0.6692, 0.6636, 0.6579, 0.6524, 0.6470, 0.6457, 0.6798]
train_acc_unet_smaller_filter = [0.7997, 0.8172, 0.8274, 0.8185, 0.8185, 0.8238, 0.8220, 0.8233, 0.8196, 0.8271]
val_acc_unet_smaller_filter = [0.8195, 0.8174, 0.8178, 0.8179, 0.8179, 0.8179, 0.8179, 0.8179, 0.8064, 0.7934]

# %%
plt.plot(epoch, train_loss_unet_smaller_filter, label = 'Train loss')
plt.plot(epoch, val_loss_unet_smaller_filter, label = 'Validation loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss by Epoch for UNet Variation 1 (Smaller Filter)')
plt.show()

# %%
plt.plot(epoch, train_acc_unet_smaller_filter, label = 'Train accuracy')
plt.plot(epoch, val_acc_unet_smaller_filter, label = 'Validation accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy by Epoch for UNet Variation 1 (Smaller Filter)')
plt.show()
